# %%
from helper import getData
import scipy.stats as stats
import matplotlib.pyplot as plt
import numpy as np

# %%
data_a = getData('distA.csv')

# %%
plt.hist(data_a)
plt.show
print("In this data A we can see that it's normal distibution")
# Out:
# In this data A we can see that it's normal distibution

# %%
stats.probplot(data_a, dist = 'norm', plot=plt)
plt.show()

# %%
data_b = getData('distB.csv')

# %%
plt.hist(data_b)
plt.show
print("In this data B we can see that it's laplace distrubution")
# Out:
# In this data B we can see that it's laplace distrubution

# %%
stats.probplot(data_a, dist = 'laplace', plot=plt)
plt.show()

# %%
data_c = getData('distC.csv')

# %%
plt.hist(data_c)
plt.show
print("In this data C we can see that it's exponential distibution")
# Out:
# In this data C we can see that it's exponential distibution

# %%
stats.probplot(data_a, dist = 'expon', plot=plt)
plt.show()
